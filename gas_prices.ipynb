# %% [markdown]
# Loading Necessary Libraries

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %% [markdown]
# Real World Examples

# %% [markdown]
# Line Graph

# %%
gas = pd.read_csv('gas_prices.csv')

plt.figure(figsize=(8,5))
plt.title('Gas prices overtime (in USD)', fontdict={'fontweight':'bold', 'fontsize':'22'})

plt.plot(gas.Year, gas.USA, 'b.-', label='United States')
plt.plot(gas.Year, gas.Canada, 'r.-', label='Canada')
plt.plot(gas.Year, gas['South Korea'], 'g.-', label='South Korea')
plt.plot(gas.Year, gas.Australia, 'y.-', label='Australia')

plt.xticks(gas.Year[::3].tolist()+[2011]) #skip every 3 years and add 2011
plt.xlabel('Year')
plt.ylabel('US Dollars')
plt.legend()

plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /workspace/study-case-analysts/gas_prices.ipynb Cell 5 line 1
#      <a href='vscode-notebook-cell://billyfrndz-studycaseana-o4odljvxd0g.ws-us108.gitpod.io/workspace/study-case-analysts/gas_prices.ipynb#W4sdnNjb2RlLXJlbW90ZQ%3D%3D?line=12'>13</a> plt.ylabel('US Dollars')
#      <a href='vscode-notebook-cell://billyfrndz-studycaseana-o4odljvxd0g.ws-us108.gitpod.io/workspace/study-case-analysts/gas_prices.ipynb#W4sdnNjb2RlLXJlbW90ZQ%3D%3D?line=13'>14</a> plt.legend()
# ---> <a href='vscode-notebook-cell://billyfrndz-studycaseana-o4odljvxd0g.ws-us108.gitpod.io/workspace/study-case-analysts/gas_prices.ipynb#W4sdnNjb2RlLXJlbW90ZQ%3D%3D?line=15'>16</a> plt.save_fig('Gas_price_figure.png', dpi=300)
#      <a href='vscode-notebook-cell://billyfrndz-studycaseana-o4odljvxd0g.ws-us108.gitpod.io/workspace/study-case-analysts/gas_prices.ipynb#W4sdnNjb2RlLXJlbW90ZQ%3D%3D?line=16'>17</a> plt.show()
#
# AttributeError: module 'matplotlib.pyplot' has no attribute 'save_fig'
